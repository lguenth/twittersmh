# %%
import pandas as pd

corpus = "/home/lukel/projekte/twittersmh/data/tweepy_v2_corpus.csv"
df = pd.read_csv(corpus, sep=";", header=None, dtype=object, names = [
        "created_at",
        "tweet_id",
        "text",
        "conversation_id",
        "author_id",
        "entities",
        "public_metrics",
        "referenced_tweets",
        "lang",
    ])

# %%
pd.set_option("display.max_colwidth", None)
df.head(5)
# Out:
#                   created_at             tweet_id  \
# 0  2021-12-28 22:37:23+00:00  1475959090853687303
# 1  2021-12-28 22:04:51+00:00  1475950903903625220
# 2  2021-12-28 22:01:03+00:00  1475949946255949829
# 3  2021-12-28 22:00:33+00:00  1475949819185217541
# 4  2021-12-28 21:45:10+00:00  1475945949147062281
#
#                                                                                                                                                                                                                                                                                                             text  \
# 0                           @bbybearcookie thanks!! i held a presentation about sophie scholl and why we can look up to her and stuff!! i was so anxious because i had to talk infront of my teacher, the principal and another teacher that actually just took notes but ah i did it i was so proud of myself!!
# 1  @WernerKulikow @RitaYaeli Ich kann es nur schwer ertragen, wenn Menschen- und Demokratiefeinde Sophie Scholl und die Weiße Rose für ihre widerwärtigen, faschistischen Ziele instrumentalisieren.\n\nSucht Ihr Euch doch bitte was Eigenes, aber beschmutzt nicht das Angedenken an die Weiße Rose!\n\nDanke.
# 2                                                                                                                                                         RT @StephFrederick6: SOPHIE SCHOLL &amp; her dear bro HANS SCHOLL\n\nHeros of right-thinking German People: employed all their wit, wisdom &amp; brav…
# 3                                                                                                                                                                   RT @historydefined: Pictured here are Hans Scholl, Sophie Scholl, and Christoph Probst who were all part of the non-violent student resista…
# 4                                                                                                                                                                   RT @historydefined: Pictured here are Hans Scholl, Sophie Scholl, and Christoph Probst who were all part of the non-violent student resista…
#
#        conversation_id            author_id  \
# 0  1475947035081777161  1188002900330647552
# 1  1475809133022650368  1445703975659982855
# 2  1475949946255949829             61740137
# 3  1475949819185217541             96894306
# 4  1475945949147062281             25924647
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                    entities  \
# 0                                                                                                                                                                                                                 {'mentions': [{'start': 0, 'end': 14, 'username': 'bbybearcookie', 'id': '1118299456384974849'}], 'annotations': [{'start': 52, 'end': 64, 'probability': 0.9896, 'type': 'Person', 'normalized_text': 'sophie scholl'}]}
# 1                                                                                                                                                                                                                                                                    {'mentions': [{'start': 0, 'end': 14, 'username': 'WernerKulikow', 'id': '714145808447356928'}, {'start': 15, 'end': 25, 'username': 'RitaYaeli', 'id': '180788381'}]}
# 2                                                                                                          {'mentions': [{'start': 3, 'end': 19, 'username': 'StephFrederick6', 'id': '1379297530790477824'}], 'annotations': [{'start': 21, 'end': 33, 'probability': 0.9703, 'type': 'Person', 'normalized_text': 'SOPHIE SCHOLL'}, {'start': 50, 'end': 60, 'probability': 0.8955, 'type': 'Person', 'normalized_text': 'HANS SCHOLL'}]}
# 3  {'mentions': [{'start': 3, 'end': 18, 'username': 'historydefined', 'id': '728409566338146304'}], 'annotations': [{'start': 38, 'end': 48, 'probability': 0.9948, 'type': 'Person', 'normalized_text': 'Hans Scholl'}, {'start': 51, 'end': 63, 'probability': 0.9979, 'type': 'Person', 'normalized_text': 'Sophie Scholl'}, {'start': 70, 'end': 85, 'probability': 0.9922, 'type': 'Person', 'normalized_text': 'Christoph Probst'}]}
# 4  {'mentions': [{'start': 3, 'end': 18, 'username': 'historydefined', 'id': '728409566338146304'}], 'annotations': [{'start': 38, 'end': 48, 'probability': 0.9948, 'type': 'Person', 'normalized_text': 'Hans Scholl'}, {'start': 51, 'end': 63, 'probability': 0.9979, 'type': 'Person', 'normalized_text': 'Sophie Scholl'}, {'start': 70, 'end': 85, 'probability': 0.9922, 'type': 'Person', 'normalized_text': 'Christoph Probst'}]}
#
#                                                                 public_metrics  \
# 0    {'retweet_count': 0, 'reply_count': 1, 'like_count': 1, 'quote_count': 0}
# 1    {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2    {'retweet_count': 4, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3  {'retweet_count': 151, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 4  {'retweet_count': 151, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
#
#                                            referenced_tweets lang
# 0  [<ReferencedTweet id=1475958424244531204 type=replied_to]   en
# 1  [<ReferencedTweet id=1475813898511167491 type=replied_to]   de
# 2   [<ReferencedTweet id=1475792710447607808 type=retweeted]   en
# 3   [<ReferencedTweet id=1466895284277940225 type=retweeted]   en
# 4   [<ReferencedTweet id=1466895284277940225 type=retweeted]   en

# %%
df.shape
# Out:
# (123747, 9)

# %%
pd.to_datetime(df["created_at"], errors="coerce")
print("These could not be converted:")
nan = df[df["created_at"].isna() == True]
nan
# Out:
# These could not be converted:
# Empty DataFrame
# Columns: [created_at, tweet_id, text, conversation_id, author_id, entities, public_metrics, referenced_tweets, lang]
# Index: []

# %%
df["day"] = df["created_at"].dt.date
df["time"] = df["created_at"].dt.time
df.sort_values(by="day", inplace=True, ignore_index=True)
df.head(5)
# Out:
#                   created_at             tweet_id  \
# 0  2021-01-01 00:03:55+00:00  1344796460496400386
# 1  2021-01-01 09:04:46+00:00  1344932566760042498
# 2  2021-01-01 03:05:40+00:00  1344842195807907841
# 3  2021-01-01 12:43:44+00:00  1344987672113246208
# 4  2021-01-01 00:59:32+00:00  1344810454191898624
#
#                                                                                                                                                                                   text  \
# 0                                         RT @Dr_Konservativ: Ich würde mich in Grund und Boden schämen Malala und Sophie Scholl auf eine Stufe mit #GretaThunberg zu stellen. Auf so…
# 1  @weisse___Rose کسی که سیگار میکشه براش اهمیتی نداره که بقیه در مورد کاراش چی بگن، اینکه تو بی حوصله ای به خودت ربط داره یا اینکه از حرف بقیه ناراحت میشی بازم به خودت ربط داره🤷🏻‍♂️
# 2                                                                                                                                               @weisse___Rose تا ده دیقه جم و جورش کن
# 3                                                          @paaleeng_sas @weisse___Rose @pinkydinkydoo0 همه ی این آتیشا از گور تو بلند میشه هااا ببین\nخودت اوردیشون حالا بیا جمع کن🤔😂
# 4                                         RT @FelixMSteiner: Frage für einen Freund: Wenn man heute Abend böllert, also gegen #Merkel und den #Faschismus, fühlt man sich dann eher w…
#
#        conversation_id            author_id  \
# 0  1344796460496400386           1868278705
# 1  1344723479090917376  1213383130192629760
# 2  1344838386289414146   950826298993242112
# 3  1344975172286242817            753638749
# 4  1344810454191898624           2763842220
#
#                                                                                                                                                                                                                                                           entities  \
# 0                                                                                             {'hashtags': [{'start': 106, 'end': 120, 'tag': 'GretaThunberg'}], 'mentions': [{'start': 3, 'end': 18, 'username': 'Dr_Konservativ', 'id': '1139431360161099776'}]}
# 1                                                                                                                                                                {'mentions': [{'start': 0, 'end': 14, 'username': 'weisse___rose', 'id': '1453131375721201665'}]}
# 2                                                                                                                                                                {'mentions': [{'start': 0, 'end': 14, 'username': 'weisse___rose', 'id': '1453131375721201665'}]}
# 3  {'mentions': [{'start': 0, 'end': 13, 'username': 'paaleeng_sas', 'id': '857832714812223488'}, {'start': 14, 'end': 28, 'username': 'weisse___rose', 'id': '1453131375721201665'}, {'start': 29, 'end': 44, 'username': 'pinkydinkydoo0', 'id': '2906397403'}]}
# 4                                                               {'hashtags': [{'start': 84, 'end': 91, 'tag': 'Merkel'}, {'start': 100, 'end': 111, 'tag': 'Faschismus'}], 'mentions': [{'start': 3, 'end': 17, 'username': 'FelixMSteiner', 'id': '1976366144'}]}
#
#                                                                public_metrics  \
# 0  {'retweet_count': 58, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 1   {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 2   {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 3   {'retweet_count': 0, 'reply_count': 1, 'like_count': 2, 'quote_count': 0}
# 4  {'retweet_count': 12, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
#
#                                            referenced_tweets lang  \
# 0   [<ReferencedTweet id=1344376699119661057 type=retweeted]   de
# 1  [<ReferencedTweet id=1344774002255032321 type=replied_to]   fa
# 2  [<ReferencedTweet id=1344841777308643328 type=replied_to]   fa
# 3  [<ReferencedTweet id=1344987509491642370 type=replied_to]   fa
# 4   [<ReferencedTweet id=1344753260993916930 type=retweeted]   de
#
#                        date         day      time
# 0 2021-01-01 00:03:55+00:00  2021-01-01  00:03:55
# 1 2021-01-01 09:04:46+00:00  2021-01-01  09:04:46
# 2 2021-01-01 03:05:40+00:00  2021-01-01  03:05:40
# 3 2021-01-01 12:43:44+00:00  2021-01-01  12:43:44
# 4 2021-01-01 00:59:32+00:00  2021-01-01  00:59:32

# %%
de = df[df["lang"] == "de"]

# %%
de.head(5)
# Out:
#                    created_at             tweet_id  \
# 0   2021-01-01 00:03:55+00:00  1344796460496400386
# 4   2021-01-01 00:59:32+00:00  1344810454191898624
# 12  2021-01-01 08:32:06+00:00  1344924348713459712
# 22  2021-01-01 08:29:48+00:00  1344923767651389440
# 23  2021-01-01 09:21:48+00:00  1344936856543240192
#
#                                                                                                                                                                                 text  \
# 0                                       RT @Dr_Konservativ: Ich würde mich in Grund und Boden schämen Malala und Sophie Scholl auf eine Stufe mit #GretaThunberg zu stellen. Auf so…
# 4                                       RT @FelixMSteiner: Frage für einen Freund: Wenn man heute Abend böllert, also gegen #Merkel und den #Faschismus, fühlt man sich dann eher w…
# 12                                      RT @Dr_Konservativ: Ich würde mich in Grund und Boden schämen Malala und Sophie Scholl auf eine Stufe mit #GretaThunberg zu stellen. Auf so…
# 22                                                         @ganonthink @reitschuster Hallo Jana aus Kassel. Hat dir Sophie Scholl nicht gereicht? Muss es nur der Schießbefehl sein?
# 23  @gluculus @RadioGuetersloh Stimmt, die momentane Lage ist von 1938 kaum zu unterscheiden. Lass mich raten, du fühlst dich sicher auch schon ein bisschen wie Sophie Scholl oder?
#
#         conversation_id            author_id  \
# 0   1344796460496400386           1868278705
# 4   1344810454191898624           2763842220
# 12  1344924348713459712  1322452419075362816
# 22  1344886069129576448            713852918
# 23  1344322212443136000            255694689
#
#                                                                                                                                                                                               entities  \
# 0                                 {'hashtags': [{'start': 106, 'end': 120, 'tag': 'GretaThunberg'}], 'mentions': [{'start': 3, 'end': 18, 'username': 'Dr_Konservativ', 'id': '1139431360161099776'}]}
# 4   {'hashtags': [{'start': 84, 'end': 91, 'tag': 'Merkel'}, {'start': 100, 'end': 111, 'tag': 'Faschismus'}], 'mentions': [{'start': 3, 'end': 17, 'username': 'FelixMSteiner', 'id': '1976366144'}]}
# 12                                {'hashtags': [{'start': 106, 'end': 120, 'tag': 'GretaThunberg'}], 'mentions': [{'start': 3, 'end': 18, 'username': 'Dr_Konservativ', 'id': '1139431360161099776'}]}
# 22                                                                                                              {'mentions': [{'start': 12, 'end': 25, 'username': 'reitschuster', 'id': '36713389'}]}
# 23                               {'mentions': [{'start': 0, 'end': 9, 'username': 'gluculus', 'id': '864853753039650816'}, {'start': 10, 'end': 26, 'username': 'RadioGuetersloh', 'id': '31376591'}]}
#
#                                                                 public_metrics  \
# 0   {'retweet_count': 58, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 4   {'retweet_count': 12, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 12  {'retweet_count': 58, 'reply_count': 0, 'like_count': 0, 'quote_count': 0}
# 22   {'retweet_count': 0, 'reply_count': 0, 'like_count': 3, 'quote_count': 0}
# 23   {'retweet_count': 0, 'reply_count': 4, 'like_count': 0, 'quote_count': 0}
#
#                                             referenced_tweets lang  \
# 0    [<ReferencedTweet id=1344376699119661057 type=retweeted]   de
# 4    [<ReferencedTweet id=1344753260993916930 type=retweeted]   de
# 12   [<ReferencedTweet id=1344376699119661057 type=retweeted]   de
# 22  [<ReferencedTweet id=1344892776941551616 type=replied_to]   de
# 23  [<ReferencedTweet id=1344327189941121030 type=replied_to]   de
#
#                         date         day      time
# 0  2021-01-01 00:03:55+00:00  2021-01-01  00:03:55
# 4  2021-01-01 00:59:32+00:00  2021-01-01  00:59:32
# 12 2021-01-01 08:32:06+00:00  2021-01-01  08:32:06
# 22 2021-01-01 08:29:48+00:00  2021-01-01  08:29:48
# 23 2021-01-01 09:21:48+00:00  2021-01-01  09:21:48
